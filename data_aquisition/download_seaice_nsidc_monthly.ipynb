# %% [markdown]
# # Downloading Sea Ice Data from NSIDC
#
# This notebook is designed to download sea ice data concentration data, available at https://nsidc.org/data/g02202/versions/4
#
# #### Import the modules for this notebook

# %%
import requests
import os

# %% [markdown]
# #### Define the destination file path

# %%
# define the path to the folder where the data will be downloaded
download_folder = '/Volumes/CoOL/Data_Repository/Arctic/Sea_Ice'

# %% [markdown]
# #### Make a list of file paths

# %%
# hemisphere and hemisphere code
hemisphere = 'north'
hemisphere_code = 'nh'

# initial satellite code
sat_code = 'n07'

# define the base url
base_url = 'https://noaadata.apps.nsidc.org/NOAA/G02202_V4/'+hemisphere+'/monthly/'

# make a list of URls corresponding to the file date
file_urls = []
for year in range(2010,2023):
    for month in range(1,13):

        # update satellite code when different satellites are used
        if year==1987 and month==8:
            sat_code = 'f08'
        if year==1992 and month==1:
            sat_code = 'f11'
        if year==1995 and month==10:
            sat_code = 'f13'
        if year==2008 and month==1:
            sat_code = 'f17'
        
        yr = str(year)
        mo = '{:02d}'.format(month)
        file_name = 'seaice_conc_monthly_'+hemisphere_code+'_'+yr+mo+'_'+sat_code+'_v04r00.nc'
        file_urls.append(base_url+'/'+file_name)

# %% [markdown]
# #### Download the data

# %%
for i in range(len(file_urls)):
    url = file_urls[i]
    
    file_name = url.split('/')[-1]
    if file_name not in os.listdir(download_folder):
    
        print('Downloading '+file_name+' (file '+str(i+1)+' of '+str(len(file_urls))+')')
    
        output_file = os.path.join(download_folder,file_name)
    
        with requests.get(url, stream=True, allow_redirects=True) as r:
            r.raise_for_status()
            with open(output_file, 'wb') as f:                   
                for chunk in r.iter_content(chunk_size=8192):   
                    f.write(chunk)
# Out:
# Downloading seaice_conc_monthly_nh_201001_f17_v04r00.nc (file 1 of 156)
# Downloading seaice_conc_monthly_nh_201002_f17_v04r00.nc (file 2 of 156)
# Downloading seaice_conc_monthly_nh_201003_f17_v04r00.nc (file 3 of 156)
# Downloading seaice_conc_monthly_nh_201004_f17_v04r00.nc (file 4 of 156)
# Downloading seaice_conc_monthly_nh_201005_f17_v04r00.nc (file 5 of 156)
# Downloading seaice_conc_monthly_nh_201006_f17_v04r00.nc (file 6 of 156)
# Downloading seaice_conc_monthly_nh_201007_f17_v04r00.nc (file 7 of 156)
# Downloading seaice_conc_monthly_nh_201008_f17_v04r00.nc (file 8 of 156)
# Downloading seaice_conc_monthly_nh_201009_f17_v04r00.nc (file 9 of 156)
# Downloading seaice_conc_monthly_nh_201010_f17_v04r00.nc (file 10 of 156)
# Downloading seaice_conc_monthly_nh_201011_f17_v04r00.nc (file 11 of 156)
# Downloading seaice_conc_monthly_nh_201012_f17_v04r00.nc (file 12 of 156)
# Downloading seaice_conc_monthly_nh_201101_f17_v04r00.nc (file 13 of 156)
# Downloading seaice_conc_monthly_nh_201102_f17_v04r00.nc (file 14 of 156)
# Downloading seaice_conc_monthly_nh_201103_f17_v04r00.nc (file 15 of 156)
# Downloading seaice_conc_monthly_nh_201104_f17_v04r00.nc (file 16 of 156)
# Downloading seaice_conc_monthly_nh_201105_f17_v04r00.nc (file 17 of 156)
# Downloading seaice_conc_monthly_nh_201106_f17_v04r00.nc (file 18 of 156)
# Downloading seaice_conc_monthly_nh_201107_f17_v04r00.nc (file 19 of 156)
# Downloading seaice_conc_monthly_nh_201108_f17_v04r00.nc (file 20 of 156)
# Downloading seaice_conc_monthly_nh_201109_f17_v04r00.nc (file 21 of 156)
# Downloading seaice_conc_monthly_nh_201110_f17_v04r00.nc (file 22 of 156)
# Downloading seaice_conc_monthly_nh_201111_f17_v04r00.nc (file 23 of 156)
# Downloading seaice_conc_monthly_nh_201112_f17_v04r00.nc (file 24 of 156)
# Downloading seaice_conc_monthly_nh_201201_f17_v04r00.nc (file 25 of 156)
# Downloading seaice_conc_monthly_nh_201202_f17_v04r00.nc (file 26 of 156)
# Downloading seaice_conc_monthly_nh_201203_f17_v04r00.nc (file 27 of 156)
# Downloading seaice_conc_monthly_nh_201204_f17_v04r00.nc (file 28 of 156)
# Downloading seaice_conc_monthly_nh_201205_f17_v04r00.nc (file 29 of 156)
# Downloading seaice_conc_monthly_nh_201206_f17_v04r00.nc (file 30 of 156)
# Downloading seaice_conc_monthly_nh_201207_f17_v04r00.nc (file 31 of 156)
# Downloading seaice_conc_monthly_nh_201208_f17_v04r00.nc (file 32 of 156)
# Downloading seaice_conc_monthly_nh_201209_f17_v04r00.nc (file 33 of 156)
# Downloading seaice_conc_monthly_nh_201210_f17_v04r00.nc (file 34 of 156)
# Downloading seaice_conc_monthly_nh_201211_f17_v04r00.nc (file 35 of 156)
# Downloading seaice_conc_monthly_nh_201212_f17_v04r00.nc (file 36 of 156)
# Downloading seaice_conc_monthly_nh_201301_f17_v04r00.nc (file 37 of 156)
# Downloading seaice_conc_monthly_nh_201302_f17_v04r00.nc (file 38 of 156)
# Downloading seaice_conc_monthly_nh_201303_f17_v04r00.nc (file 39 of 156)
# Downloading seaice_conc_monthly_nh_201304_f17_v04r00.nc (file 40 of 156)
# Downloading seaice_conc_monthly_nh_201305_f17_v04r00.nc (file 41 of 156)
# Downloading seaice_conc_monthly_nh_201306_f17_v04r00.nc (file 42 of 156)
# Downloading seaice_conc_monthly_nh_201307_f17_v04r00.nc (file 43 of 156)
# Downloading seaice_conc_monthly_nh_201308_f17_v04r00.nc (file 44 of 156)
# Downloading seaice_conc_monthly_nh_201309_f17_v04r00.nc (file 45 of 156)
# Downloading seaice_conc_monthly_nh_201310_f17_v04r00.nc (file 46 of 156)
# Downloading seaice_conc_monthly_nh_201311_f17_v04r00.nc (file 47 of 156)
# Downloading seaice_conc_monthly_nh_201312_f17_v04r00.nc (file 48 of 156)
# Downloading seaice_conc_monthly_nh_201401_f17_v04r00.nc (file 49 of 156)
# Downloading seaice_conc_monthly_nh_201402_f17_v04r00.nc (file 50 of 156)
# Downloading seaice_conc_monthly_nh_201403_f17_v04r00.nc (file 51 of 156)
# Downloading seaice_conc_monthly_nh_201404_f17_v04r00.nc (file 52 of 156)
# Downloading seaice_conc_monthly_nh_201405_f17_v04r00.nc (file 53 of 156)
# Downloading seaice_conc_monthly_nh_201406_f17_v04r00.nc (file 54 of 156)
# Downloading seaice_conc_monthly_nh_201407_f17_v04r00.nc (file 55 of 156)
# Downloading seaice_conc_monthly_nh_201408_f17_v04r00.nc (file 56 of 156)
# Downloading seaice_conc_monthly_nh_201409_f17_v04r00.nc (file 57 of 156)
# Downloading seaice_conc_monthly_nh_201410_f17_v04r00.nc (file 58 of 156)
# Downloading seaice_conc_monthly_nh_201411_f17_v04r00.nc (file 59 of 156)
# Downloading seaice_conc_monthly_nh_201412_f17_v04r00.nc (file 60 of 156)
# Downloading seaice_conc_monthly_nh_201501_f17_v04r00.nc (file 61 of 156)
# Downloading seaice_conc_monthly_nh_201502_f17_v04r00.nc (file 62 of 156)
# Downloading seaice_conc_monthly_nh_201503_f17_v04r00.nc (file 63 of 156)
# Downloading seaice_conc_monthly_nh_201504_f17_v04r00.nc (file 64 of 156)
# Downloading seaice_conc_monthly_nh_201505_f17_v04r00.nc (file 65 of 156)
# Downloading seaice_conc_monthly_nh_201506_f17_v04r00.nc (file 66 of 156)
# Downloading seaice_conc_monthly_nh_201507_f17_v04r00.nc (file 67 of 156)
# Downloading seaice_conc_monthly_nh_201508_f17_v04r00.nc (file 68 of 156)
# Downloading seaice_conc_monthly_nh_201509_f17_v04r00.nc (file 69 of 156)
# Downloading seaice_conc_monthly_nh_201510_f17_v04r00.nc (file 70 of 156)
# Downloading seaice_conc_monthly_nh_201511_f17_v04r00.nc (file 71 of 156)
# Downloading seaice_conc_monthly_nh_201512_f17_v04r00.nc (file 72 of 156)
# Downloading seaice_conc_monthly_nh_201601_f17_v04r00.nc (file 73 of 156)
# Downloading seaice_conc_monthly_nh_201602_f17_v04r00.nc (file 74 of 156)
# Downloading seaice_conc_monthly_nh_201603_f17_v04r00.nc (file 75 of 156)
# Downloading seaice_conc_monthly_nh_201604_f17_v04r00.nc (file 76 of 156)
# Downloading seaice_conc_monthly_nh_201605_f17_v04r00.nc (file 77 of 156)
# Downloading seaice_conc_monthly_nh_201606_f17_v04r00.nc (file 78 of 156)
# Downloading seaice_conc_monthly_nh_201607_f17_v04r00.nc (file 79 of 156)
# Downloading seaice_conc_monthly_nh_201608_f17_v04r00.nc (file 80 of 156)
# Downloading seaice_conc_monthly_nh_201609_f17_v04r00.nc (file 81 of 156)
# Downloading seaice_conc_monthly_nh_201610_f17_v04r00.nc (file 82 of 156)
# Downloading seaice_conc_monthly_nh_201611_f17_v04r00.nc (file 83 of 156)
# Downloading seaice_conc_monthly_nh_201612_f17_v04r00.nc (file 84 of 156)
# Downloading seaice_conc_monthly_nh_201701_f17_v04r00.nc (file 85 of 156)
# Downloading seaice_conc_monthly_nh_201702_f17_v04r00.nc (file 86 of 156)
# Downloading seaice_conc_monthly_nh_201703_f17_v04r00.nc (file 87 of 156)
# Downloading seaice_conc_monthly_nh_201704_f17_v04r00.nc (file 88 of 156)
# Downloading seaice_conc_monthly_nh_201705_f17_v04r00.nc (file 89 of 156)
# Downloading seaice_conc_monthly_nh_201706_f17_v04r00.nc (file 90 of 156)
# Downloading seaice_conc_monthly_nh_201707_f17_v04r00.nc (file 91 of 156)
# Downloading seaice_conc_monthly_nh_201708_f17_v04r00.nc (file 92 of 156)
# Downloading seaice_conc_monthly_nh_201709_f17_v04r00.nc (file 93 of 156)
# Downloading seaice_conc_monthly_nh_201710_f17_v04r00.nc (file 94 of 156)
# Downloading seaice_conc_monthly_nh_201711_f17_v04r00.nc (file 95 of 156)
# Downloading seaice_conc_monthly_nh_201712_f17_v04r00.nc (file 96 of 156)
# Downloading seaice_conc_monthly_nh_201801_f17_v04r00.nc (file 97 of 156)
# Downloading seaice_conc_monthly_nh_201802_f17_v04r00.nc (file 98 of 156)
# Downloading seaice_conc_monthly_nh_201803_f17_v04r00.nc (file 99 of 156)
# Downloading seaice_conc_monthly_nh_201804_f17_v04r00.nc (file 100 of 156)
# Downloading seaice_conc_monthly_nh_201805_f17_v04r00.nc (file 101 of 156)
# Downloading seaice_conc_monthly_nh_201806_f17_v04r00.nc (file 102 of 156)
# Downloading seaice_conc_monthly_nh_201807_f17_v04r00.nc (file 103 of 156)
# Downloading seaice_conc_monthly_nh_201808_f17_v04r00.nc (file 104 of 156)
# Downloading seaice_conc_monthly_nh_201809_f17_v04r00.nc (file 105 of 156)
# Downloading seaice_conc_monthly_nh_201810_f17_v04r00.nc (file 106 of 156)
# Downloading seaice_conc_monthly_nh_201811_f17_v04r00.nc (file 107 of 156)
# Downloading seaice_conc_monthly_nh_201812_f17_v04r00.nc (file 108 of 156)
# Downloading seaice_conc_monthly_nh_201901_f17_v04r00.nc (file 109 of 156)
# Downloading seaice_conc_monthly_nh_201902_f17_v04r00.nc (file 110 of 156)
# Downloading seaice_conc_monthly_nh_201903_f17_v04r00.nc (file 111 of 156)
# Downloading seaice_conc_monthly_nh_201904_f17_v04r00.nc (file 112 of 156)
# Downloading seaice_conc_monthly_nh_201905_f17_v04r00.nc (file 113 of 156)
# Downloading seaice_conc_monthly_nh_201906_f17_v04r00.nc (file 114 of 156)
# Downloading seaice_conc_monthly_nh_201907_f17_v04r00.nc (file 115 of 156)
# Downloading seaice_conc_monthly_nh_201908_f17_v04r00.nc (file 116 of 156)
# Downloading seaice_conc_monthly_nh_201909_f17_v04r00.nc (file 117 of 156)
# Downloading seaice_conc_monthly_nh_201910_f17_v04r00.nc (file 118 of 156)
# Downloading seaice_conc_monthly_nh_201911_f17_v04r00.nc (file 119 of 156)
# Downloading seaice_conc_monthly_nh_201912_f17_v04r00.nc (file 120 of 156)
# Downloading seaice_conc_monthly_nh_202001_f17_v04r00.nc (file 121 of 156)
# Downloading seaice_conc_monthly_nh_202002_f17_v04r00.nc (file 122 of 156)
# Downloading seaice_conc_monthly_nh_202003_f17_v04r00.nc (file 123 of 156)
# Downloading seaice_conc_monthly_nh_202004_f17_v04r00.nc (file 124 of 156)
# Downloading seaice_conc_monthly_nh_202005_f17_v04r00.nc (file 125 of 156)
# Downloading seaice_conc_monthly_nh_202006_f17_v04r00.nc (file 126 of 156)
# Downloading seaice_conc_monthly_nh_202007_f17_v04r00.nc (file 127 of 156)
# Downloading seaice_conc_monthly_nh_202008_f17_v04r00.nc (file 128 of 156)
# Downloading seaice_conc_monthly_nh_202009_f17_v04r00.nc (file 129 of 156)
# Downloading seaice_conc_monthly_nh_202010_f17_v04r00.nc (file 130 of 156)
# Downloading seaice_conc_monthly_nh_202011_f17_v04r00.nc (file 131 of 156)
# Downloading seaice_conc_monthly_nh_202012_f17_v04r00.nc (file 132 of 156)
# Downloading seaice_conc_monthly_nh_202101_f17_v04r00.nc (file 133 of 156)
# Downloading seaice_conc_monthly_nh_202102_f17_v04r00.nc (file 134 of 156)
# Downloading seaice_conc_monthly_nh_202103_f17_v04r00.nc (file 135 of 156)
# Downloading seaice_conc_monthly_nh_202104_f17_v04r00.nc (file 136 of 156)
# Downloading seaice_conc_monthly_nh_202105_f17_v04r00.nc (file 137 of 156)
# Downloading seaice_conc_monthly_nh_202106_f17_v04r00.nc (file 138 of 156)
# Downloading seaice_conc_monthly_nh_202107_f17_v04r00.nc (file 139 of 156)
# Downloading seaice_conc_monthly_nh_202108_f17_v04r00.nc (file 140 of 156)
# Downloading seaice_conc_monthly_nh_202109_f17_v04r00.nc (file 141 of 156)
# Downloading seaice_conc_monthly_nh_202110_f17_v04r00.nc (file 142 of 156)
# Downloading seaice_conc_monthly_nh_202111_f17_v04r00.nc (file 143 of 156)
# Downloading seaice_conc_monthly_nh_202112_f17_v04r00.nc (file 144 of 156)
# Downloading seaice_conc_monthly_nh_202201_f17_v04r00.nc (file 145 of 156)
# Downloading seaice_conc_monthly_nh_202202_f17_v04r00.nc (file 146 of 156)
# Downloading seaice_conc_monthly_nh_202203_f17_v04r00.nc (file 147 of 156)
# Downloading seaice_conc_monthly_nh_202204_f17_v04r00.nc (file 148 of 156)
# Downloading seaice_conc_monthly_nh_202205_f17_v04r00.nc (file 149 of 156)
# Downloading seaice_conc_monthly_nh_202206_f17_v04r00.nc (file 150 of 156)
# Downloading seaice_conc_monthly_nh_202207_f17_v04r00.nc (file 151 of 156)
# Downloading seaice_conc_monthly_nh_202208_f17_v04r00.nc (file 152 of 156)
# Downloading seaice_conc_monthly_nh_202209_f17_v04r00.nc (file 153 of 156)
# Downloading seaice_conc_monthly_nh_202210_f17_v04r00.nc (file 154 of 156)
# Downloading seaice_conc_monthly_nh_202211_f17_v04r00.nc (file 155 of 156)
# Downloading seaice_conc_monthly_nh_202212_f17_v04r00.nc (file 156 of 156)

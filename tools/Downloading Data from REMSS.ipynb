# %% [markdown]
# # Downloading Sea Ice Data from REMSS
#
# This notebook is designed to download sea ice data concentration data, available at https://data.remss.com/ccmp/v03.0/
#
# #### Import the modules for this notebook

# %%
import requests
import os
import datetime as dt

# %% [markdown]
# #### User Inputs
# Make a path to the download folder and specify the date range

# %%
# define the path to the folder where the data will be downloaded
download_folder = '/Users/mike/Documents/Teaching/Courses/MS 274/Data/Wind'

# define the start date
start_year = 2010
start_month = 1
start_day = 1

# defin the end date
end_year = 2020
end_month = 1
end_day = 31

# %% [markdown]
# #### Make a list of file paths

# %%
# choose the subset (daily or monthly)
subset = 'monthly'

# define the base url
base_url = 'https://data.remss.com/ccmp/v03.0'

# define the date range

# make a list of URls corresponding to the file date
file_urls = []
for year in range(1979,2023):
    for month in range(1,13):

        if subset=='daily':
            if month in [1,3,5,7,8,10,12]:
                n_days = 31
            elif month in [4,6,9,11]:
                n_days = 30
            else:
                if year%4==0:
                    n_days = 29
                else:
                    n_days = 28
                    
            for day in range(1,n_days+1):
                date = dt.datetime(year, month, day)
                if date >= dt.datetime(start_year, start_month, start_day) and date <= dt.datetime(end_year, end_month, end_day):
                    yr = str(year)
                    mo = '{:02d}'.format(month)
                    dy = '{:02d}'.format(day)
                    file_name = 'CCMP_Wind_Analysis_'+yr+mo+dy+'_V03.0_L4.0.nc'
                    file_urls.append(base_url+'/daily/y'+str(year)+'/m'+mo+'/'+file_name)

        elif subset=='monthly':
            day=15
            date = dt.datetime(year, month, day)
            if date >= dt.datetime(start_year, start_month, start_day) and date <= dt.datetime(end_year, end_month, end_day):
                yr = str(year)
                mo = '{:02d}'.format(month)
                file_name = 'CCMP_Wind_Analysis_'+yr+mo+'_V03.0_L4.5.nc'
                file_urls.append(base_url+'/monthly/y'+str(year)+'/m'+mo+'/'+file_name)

        else:
            raise ValueError('subset not recognized')

# %% [markdown]
# #### Download the data

# %%
for i in range(len(file_urls)):
    url = file_urls[i]
    
    file_name = url.split('/')[-1]
    if file_name not in os.listdir(download_folder):
    
        print('Downloading '+file_name+' (file '+str(i+1)+' of '+str(len(file_urls))+')')
    
        output_file = os.path.join(download_folder,file_name)
    
        with requests.get(url, stream=True, allow_redirects=True) as r:
            r.raise_for_status()
            with open(output_file, 'wb') as f:                   
                for chunk in r.iter_content(chunk_size=8192):   
                    f.write(chunk)
# Out:
# Downloading CCMP_Wind_Analysis_201001_V03.0_L4.5.nc (file 1 of 121)
# Downloading CCMP_Wind_Analysis_201002_V03.0_L4.5.nc (file 2 of 121)
# Downloading CCMP_Wind_Analysis_201003_V03.0_L4.5.nc (file 3 of 121)
# Downloading CCMP_Wind_Analysis_201004_V03.0_L4.5.nc (file 4 of 121)
# Downloading CCMP_Wind_Analysis_201005_V03.0_L4.5.nc (file 5 of 121)
# Downloading CCMP_Wind_Analysis_201006_V03.0_L4.5.nc (file 6 of 121)
# Downloading CCMP_Wind_Analysis_201007_V03.0_L4.5.nc (file 7 of 121)
# Downloading CCMP_Wind_Analysis_201008_V03.0_L4.5.nc (file 8 of 121)
# Downloading CCMP_Wind_Analysis_201009_V03.0_L4.5.nc (file 9 of 121)
# Downloading CCMP_Wind_Analysis_201010_V03.0_L4.5.nc (file 10 of 121)
# Downloading CCMP_Wind_Analysis_201011_V03.0_L4.5.nc (file 11 of 121)
# Downloading CCMP_Wind_Analysis_201012_V03.0_L4.5.nc (file 12 of 121)
# Downloading CCMP_Wind_Analysis_201101_V03.0_L4.5.nc (file 13 of 121)
# Downloading CCMP_Wind_Analysis_201102_V03.0_L4.5.nc (file 14 of 121)
# Downloading CCMP_Wind_Analysis_201103_V03.0_L4.5.nc (file 15 of 121)
# Downloading CCMP_Wind_Analysis_201104_V03.0_L4.5.nc (file 16 of 121)
# Downloading CCMP_Wind_Analysis_201105_V03.0_L4.5.nc (file 17 of 121)
# Downloading CCMP_Wind_Analysis_201106_V03.0_L4.5.nc (file 18 of 121)
# Downloading CCMP_Wind_Analysis_201107_V03.0_L4.5.nc (file 19 of 121)
# Downloading CCMP_Wind_Analysis_201108_V03.0_L4.5.nc (file 20 of 121)
# Downloading CCMP_Wind_Analysis_201109_V03.0_L4.5.nc (file 21 of 121)
# Downloading CCMP_Wind_Analysis_201110_V03.0_L4.5.nc (file 22 of 121)
# Downloading CCMP_Wind_Analysis_201111_V03.0_L4.5.nc (file 23 of 121)
# Downloading CCMP_Wind_Analysis_201112_V03.0_L4.5.nc (file 24 of 121)
# Downloading CCMP_Wind_Analysis_201201_V03.0_L4.5.nc (file 25 of 121)
# Downloading CCMP_Wind_Analysis_201202_V03.0_L4.5.nc (file 26 of 121)
# Downloading CCMP_Wind_Analysis_201203_V03.0_L4.5.nc (file 27 of 121)
# Downloading CCMP_Wind_Analysis_201204_V03.0_L4.5.nc (file 28 of 121)
# Downloading CCMP_Wind_Analysis_201205_V03.0_L4.5.nc (file 29 of 121)
# Downloading CCMP_Wind_Analysis_201206_V03.0_L4.5.nc (file 30 of 121)
# Downloading CCMP_Wind_Analysis_201207_V03.0_L4.5.nc (file 31 of 121)
# Downloading CCMP_Wind_Analysis_201208_V03.0_L4.5.nc (file 32 of 121)
# Downloading CCMP_Wind_Analysis_201209_V03.0_L4.5.nc (file 33 of 121)
# Downloading CCMP_Wind_Analysis_201210_V03.0_L4.5.nc (file 34 of 121)
# Downloading CCMP_Wind_Analysis_201211_V03.0_L4.5.nc (file 35 of 121)
# Downloading CCMP_Wind_Analysis_201212_V03.0_L4.5.nc (file 36 of 121)
# Downloading CCMP_Wind_Analysis_201301_V03.0_L4.5.nc (file 37 of 121)
# Downloading CCMP_Wind_Analysis_201302_V03.0_L4.5.nc (file 38 of 121)
# Downloading CCMP_Wind_Analysis_201303_V03.0_L4.5.nc (file 39 of 121)
# Downloading CCMP_Wind_Analysis_201304_V03.0_L4.5.nc (file 40 of 121)
# Downloading CCMP_Wind_Analysis_201305_V03.0_L4.5.nc (file 41 of 121)
# Downloading CCMP_Wind_Analysis_201306_V03.0_L4.5.nc (file 42 of 121)
# Downloading CCMP_Wind_Analysis_201307_V03.0_L4.5.nc (file 43 of 121)
# Downloading CCMP_Wind_Analysis_201308_V03.0_L4.5.nc (file 44 of 121)
# Downloading CCMP_Wind_Analysis_201309_V03.0_L4.5.nc (file 45 of 121)
# Downloading CCMP_Wind_Analysis_201310_V03.0_L4.5.nc (file 46 of 121)
# Downloading CCMP_Wind_Analysis_201311_V03.0_L4.5.nc (file 47 of 121)
# Downloading CCMP_Wind_Analysis_201312_V03.0_L4.5.nc (file 48 of 121)
# Downloading CCMP_Wind_Analysis_201401_V03.0_L4.5.nc (file 49 of 121)
# Downloading CCMP_Wind_Analysis_201402_V03.0_L4.5.nc (file 50 of 121)
# Downloading CCMP_Wind_Analysis_201403_V03.0_L4.5.nc (file 51 of 121)
# Downloading CCMP_Wind_Analysis_201404_V03.0_L4.5.nc (file 52 of 121)
# Downloading CCMP_Wind_Analysis_201405_V03.0_L4.5.nc (file 53 of 121)
# Downloading CCMP_Wind_Analysis_201406_V03.0_L4.5.nc (file 54 of 121)
# Downloading CCMP_Wind_Analysis_201407_V03.0_L4.5.nc (file 55 of 121)
# Downloading CCMP_Wind_Analysis_201408_V03.0_L4.5.nc (file 56 of 121)
# Downloading CCMP_Wind_Analysis_201409_V03.0_L4.5.nc (file 57 of 121)
# Downloading CCMP_Wind_Analysis_201410_V03.0_L4.5.nc (file 58 of 121)
# Downloading CCMP_Wind_Analysis_201411_V03.0_L4.5.nc (file 59 of 121)
# Downloading CCMP_Wind_Analysis_201412_V03.0_L4.5.nc (file 60 of 121)
# Downloading CCMP_Wind_Analysis_201501_V03.0_L4.5.nc (file 61 of 121)
# Downloading CCMP_Wind_Analysis_201502_V03.0_L4.5.nc (file 62 of 121)
# Downloading CCMP_Wind_Analysis_201503_V03.0_L4.5.nc (file 63 of 121)
# Downloading CCMP_Wind_Analysis_201504_V03.0_L4.5.nc (file 64 of 121)
# Downloading CCMP_Wind_Analysis_201505_V03.0_L4.5.nc (file 65 of 121)
# Downloading CCMP_Wind_Analysis_201506_V03.0_L4.5.nc (file 66 of 121)
# Downloading CCMP_Wind_Analysis_201507_V03.0_L4.5.nc (file 67 of 121)
# Downloading CCMP_Wind_Analysis_201508_V03.0_L4.5.nc (file 68 of 121)
# Downloading CCMP_Wind_Analysis_201509_V03.0_L4.5.nc (file 69 of 121)
# Downloading CCMP_Wind_Analysis_201510_V03.0_L4.5.nc (file 70 of 121)
# Downloading CCMP_Wind_Analysis_201511_V03.0_L4.5.nc (file 71 of 121)
# Downloading CCMP_Wind_Analysis_201512_V03.0_L4.5.nc (file 72 of 121)
# Downloading CCMP_Wind_Analysis_201601_V03.0_L4.5.nc (file 73 of 121)
# Downloading CCMP_Wind_Analysis_201602_V03.0_L4.5.nc (file 74 of 121)
# Downloading CCMP_Wind_Analysis_201603_V03.0_L4.5.nc (file 75 of 121)
# Downloading CCMP_Wind_Analysis_201604_V03.0_L4.5.nc (file 76 of 121)
# Downloading CCMP_Wind_Analysis_201605_V03.0_L4.5.nc (file 77 of 121)
# Downloading CCMP_Wind_Analysis_201606_V03.0_L4.5.nc (file 78 of 121)
# Downloading CCMP_Wind_Analysis_201607_V03.0_L4.5.nc (file 79 of 121)
# Downloading CCMP_Wind_Analysis_201608_V03.0_L4.5.nc (file 80 of 121)
# Downloading CCMP_Wind_Analysis_201609_V03.0_L4.5.nc (file 81 of 121)
# Downloading CCMP_Wind_Analysis_201610_V03.0_L4.5.nc (file 82 of 121)
# Downloading CCMP_Wind_Analysis_201611_V03.0_L4.5.nc (file 83 of 121)
# Downloading CCMP_Wind_Analysis_201612_V03.0_L4.5.nc (file 84 of 121)
# Downloading CCMP_Wind_Analysis_201701_V03.0_L4.5.nc (file 85 of 121)
# Downloading CCMP_Wind_Analysis_201702_V03.0_L4.5.nc (file 86 of 121)
# Downloading CCMP_Wind_Analysis_201703_V03.0_L4.5.nc (file 87 of 121)
# Downloading CCMP_Wind_Analysis_201704_V03.0_L4.5.nc (file 88 of 121)
# Downloading CCMP_Wind_Analysis_201705_V03.0_L4.5.nc (file 89 of 121)
# Downloading CCMP_Wind_Analysis_201706_V03.0_L4.5.nc (file 90 of 121)
# Downloading CCMP_Wind_Analysis_201707_V03.0_L4.5.nc (file 91 of 121)
# Downloading CCMP_Wind_Analysis_201708_V03.0_L4.5.nc (file 92 of 121)
# Downloading CCMP_Wind_Analysis_201709_V03.0_L4.5.nc (file 93 of 121)
# Downloading CCMP_Wind_Analysis_201710_V03.0_L4.5.nc (file 94 of 121)
# Downloading CCMP_Wind_Analysis_201711_V03.0_L4.5.nc (file 95 of 121)
# Downloading CCMP_Wind_Analysis_201712_V03.0_L4.5.nc (file 96 of 121)
# Downloading CCMP_Wind_Analysis_201801_V03.0_L4.5.nc (file 97 of 121)
# Downloading CCMP_Wind_Analysis_201802_V03.0_L4.5.nc (file 98 of 121)
# Downloading CCMP_Wind_Analysis_201803_V03.0_L4.5.nc (file 99 of 121)
